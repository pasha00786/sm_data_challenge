# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
data = pd.read_csv('train__updated.csv')
data.head()
# Out:
#      index  year  month  day  hour  latitude  longitude  imma_version  \
# 0  train_0  1978      1    1   0.0      48.8     -126.0             1
# 1  train_1  1978      1    1   0.0      49.7     -127.9             1
# 2  train_2  1978      1    1   0.0      50.9     -129.9             1
# 3  train_3  1978      1    1   0.0      51.4     -128.8             1
# 4  train_4  1978      1    1   0.0      49.3     -123.7             1
#
#    attm_count  time_indicator            ...             platform_type  \
# 0           4             NaN            ...                       6.0
# 1           4             NaN            ...                       6.0
# 2           4             NaN            ...                       6.0
# 3           4             NaN            ...                       6.0
# 4           4             NaN            ...                       6.0
#
#    dup_status  dup_check  nightday_flag  source_exclusion_flags  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 54 columns):
# index                        50000 non-null object
# year                         50000 non-null int64
# month                        50000 non-null int64
# day                          50000 non-null int64
# hour                         50000 non-null float64
# latitude                     50000 non-null float64
# longitude                    50000 non-null float64
# imma_version                 50000 non-null int64
# attm_count                   50000 non-null int64
# time_indicator               1257 non-null float64
# latlong_indicator            50000 non-null int64
# ship_course                  1208 non-null float64
# ship_speed                   1208 non-null float64
# national_source_indicator    101 non-null float64
# id_indicator                 50000 non-null int64
# wind_direction_indicator     50000 non-null int64
# ...

# %%
data['one_degree_box_number'].value_counts()
# Out:
# 84    7076
# 83    6686
# 74    4553
# 95    3482
# 18    3468
# 29    3396
# 38    3386
# 93    3383
# 9     3372
# 86    3355
# 65    3311
# 97    2640
# 64    1026
# 85     108
# 75      67
# 82      65
# 55      59
# 72      57
# 8       47
# 94      39
# 19      36
# 96      35
# 98      34
# 99      29
# 87      28
# 88      25
# 89      24
# 6       23
# 69      20
# 5       18
# 7       17
# 76      16
# 77      16
# 56      13
# 68      12
# 39      12
# 54      12
# 17      10
# 28      10
# 78       8
# 66       6
# 67       6
# 59       4
# 58       3
# 27       2
# 79       2
# 63       1
# 57       1
# 16       1
# Name: one_degree_box_number, dtype: int64

# %%
columns_to_remove = ['time_indicator','dpt_indicator','source_exclusion_flags','imma_version','attm_count','latlong_indicator','dup_check','release_no_primary','release_no_tertiary','release_status_indicator','intermediate_reject_flag']

# %%
df = data.drop(columns_to_remove, axis = 1)

# %%
tot_columns = list(df.columns)
tot_columns = tot_columns[:1]
tot_columns
# Out:
# ['index']

# %%
for col in tot_columns:
    data = df[col].dropna()
    plt.hist(data)
    print(col ,df[col].isnull().sum() )
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-ac30107d5478> in <module>()
#       1 for col in tot_columns:
#       2     data = df[col].dropna()
# ----> 3     plt.hist(data)
#       4     print(col ,df[col].isnull().sum() )
#       5     plt.show()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, hold, data, **kwargs)
#    3130                       histtype=histtype, align=align, orientation=orientation,
#    3131                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3132                       stacked=stacked, normed=normed, data=data, **kwargs)
#    3133     finally:
#    3134         ax._hold = washold
#
# ...
